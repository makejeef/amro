# %%
airnav='http://tp3.sichuanair.com:8000/airnavx/search/text'

# %%
post_data={'330':{'filterType': 'tailNumber',
                      'maxResults': '21',
                      'msnBinding': {"actype":["A330"],"customization":["CSC"]},
                      'revId': '654749_SGML_C',
                      'searchMode':'document.toc'},
               '350':{'filterType': 'tailNumber',
                      'maxResults': '21',
                      'msnBinding': {"actype":["A350"],"customization":["CSC"]},
                      'revId': '655658_S1KD_C',
                      'searchMode':'document.toc'}}

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0',}

# %%
import requests

# %%
l=requests.get(airnav,data=post_data['330'],headers=headers,cookies=air_cookie)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9432\3777479745.py in <module>
# ----> 1 l=requests.get(airnav,data=post_data['330'],headers=headers,cookies=air_cookie)
#
# NameError: name 'air_cookie' is not defined

# %%
l=requests.get(airnav,data=post_data['330'],headers=headers)
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9432\1162505479.py in <module>
# ----> 1 l=requests.get(airnav,data=post_data['330'],headers=headers)
#
# D:\Program Files\anaconda\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# D:\Program Files\anaconda\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ...

# %%
python amro_airnav.py_fun
# Out:
#   File "C:\Users\makej\AppData\Local\Temp\ipykernel_12624\3461753957.py", line 1
#     python amro_airnav.py_fun
#            ^
# SyntaxError: invalid syntax

# %%
amro_airnav.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12624\1836120964.py in <module>
# ----> 1 amro_airnav.py
#
# NameError: name 'amro_airnav' is not defined

# %%
python amro_airnav.py
# Out:
#   File "C:\Users\makej\AppData\Local\Temp\ipykernel_12624\3701092859.py", line 1
#     python amro_airnav.py
#            ^
# SyntaxError: invalid syntax

# %%
run amro_airnav.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# D:\learing\airnavX\amro\amro_airnav.py in <module>
#       5 @author: makej
#       6 """
# ----> 7 import requests,time,json,ddddocr,re
#       8
#       9 import pandas as pd
#
# ModuleNotFoundError: No module named 'ddddocr'

# %%
import ddddocr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12624\3722657938.py in <module>
# ----> 1 import ddddocr
#
# ModuleNotFoundError: No module named 'ddddocr'

# %%
pip install ddddocr
# Out:
# ...
#      ---------------------------------------- 75.9/75.9 MB 9.5 MB/s eta 0:00:00
# ...
#      --------------------------------------- 38.5/38.5 MB 11.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 5.6/5.6 MB 18.8 MB/s eta 0:00:00
# ...
#      ------------------------------------- 426.9/426.9 kB 26.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 46.0/46.0 kB ? eta 0:00:00
# ...
#      --------------------------------------- 15.8/15.8 MB 16.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 86.8/86.8 kB 4.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 95.2/95.2 kB 5.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import ddddocr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12624\3722657938.py in <module>
# ----> 1 import ddddocr
#
# ModuleNotFoundError: No module named 'ddddocr'

# %% [raw]
# import ddddocr

# %%
pip install ddddocr
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import ddddocr

# %%
s='3号主轮'

# %%
import re

# %%
if re.search('3',s):
    print(s)
# Out:
# 3号主轮

# %%
import pandas as pd

# %%
dict_from_csv=pd.read_csv('350.csv',header=None, index_col=0, squeeze=True).to_dict()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dict_from_csv=pd.read_csv('350.csv',header=None, index_col=0, squeeze=True).to_dict()
#
# TypeError: read_csv() got an unexpected keyword argument 'squeeze'

# %%
dict_from_csv=pd.read_csv('350.csv',header=None,index_col=0).to_dict()

# %%
print(dict_from_csv)
# Out:
# {1: {'0': '1', '2019-04-28': '2019-05-10', '2019-04-26': '2019-05-04', '2019-04-21': '2019-05-14', '2019-07-03': '2019-07-03', '2023-03-21': '2023-03-25', '2024-01-18': '2024-01-20', nan: nan}, 2: {'0': '2', '2019-04-28': '2019-06-06', '2019-04-26': '2019-05-28', '2019-04-21': '2019-06-09', '2019-07-03': '2019-07-03', '2023-03-21': '2023-03-27', '2024-01-18': '2024-01-22', nan: nan}, 3: {'0': '3', '2019-04-28': '2019-06-08', '2019-04-26': '2019-06-03', '2019-04-21': '2019-06-14', '2019-07-03': '2019-07-14', '2023-03-21': '2023-04-01', '2024-01-18': '2024-01-22', nan: nan}, 4: {'0': '4', '2019-04-28': '2019-06-08', '2019-04-26': '2019-06-04', '2019-04-21': '2019-06-18', '2019-07-03': '2019-07-24', '2023-03-21': '2023-04-06', '2024-01-18': '2024-01-26', nan: nan}, 5: {'0': '5', '2019-04-28': '2019-06-13', '2019-04-26': '2019-06-07', '2019-04-21': '2019-07-13', '2019-07-03': '2019-08-15', '2023-03-21': '2023-04-12', '2024-01-18': '2024-02-02', nan: nan}, 6: {'0': '6', '2019-04-28': '201
# ...

# %%
d=dict_from_csv

# %%
d[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 d[0]
#
# KeyError: 0

# %%
d
# Out:
# {1: {'0': '1',
#   '2019-04-28': '2019-05-10',
#   '2019-04-26': '2019-05-04',
#   '2019-04-21': '2019-05-14',
#   '2019-07-03': '2019-07-03',
#   '2023-03-21': '2023-03-25',
#   '2024-01-18': '2024-01-20',
#   nan: nan},
#  2: {'0': '2',
#   '2019-04-28': '2019-06-06',
#   '2019-04-26': '2019-05-28',
#   '2019-04-21': '2019-06-09',
#   '2019-07-03': '2019-07-03',
#   '2023-03-21': '2023-03-27',
#   '2024-01-18': '2024-01-22',
#   nan: nan},
#  3: {'0': '3',
#   '2019-04-28': '2019-06-08',
#   '2019-04-26': '2019-06-03',
#   '2019-04-21': '2019-06-14',
#   '2019-07-03': '2019-07-14',
#   '2023-03-21': '2023-04-01',
#   '2024-01-18': '2024-01-22',
#   nan: nan},
#  4: {'0': '4',
#   '2019-04-28': '2019-06-08',
#   '2019-04-26': '2019-06-04',
#   '2019-04-21': '2019-06-18',
#   '2019-07-03': '2019-07-24',
#   '2023-03-21': '2023-04-06',
#   '2024-01-18': '2024-01-26',
#   nan: nan},
#  5: {'0': '5',
#   '2019-04-28': '2019-06-13',
#   '2019-04-26': '2019-06-07',
# ...

# %%
d=pd.read_csv('350.csv',header=None,index_col=0).to_dict()

# %%
d
# Out:
# {1: {'0': '1',
#   '2019-04-28': '2019-05-10',
#   '2019-04-26': '2019-05-04',
#   '2019-04-21': '2019-05-14',
#   '2019-07-03': '2019-07-03',
#   '2023-03-21': '2023-03-25',
#   '2024-01-18': '2024-01-20',
#   nan: nan},
#  2: {'0': '2',
#   '2019-04-28': '2019-06-06',
#   '2019-04-26': '2019-05-28',
#   '2019-04-21': '2019-06-09',
#   '2019-07-03': '2019-07-03',
#   '2023-03-21': '2023-03-27',
#   '2024-01-18': '2024-01-22',
#   nan: nan},
#  3: {'0': '3',
#   '2019-04-28': '2019-06-08',
#   '2019-04-26': '2019-06-03',
#   '2019-04-21': '2019-06-14',
#   '2019-07-03': '2019-07-14',
#   '2023-03-21': '2023-04-01',
#   '2024-01-18': '2024-01-22',
#   nan: nan},
#  4: {'0': '4',
#   '2019-04-28': '2019-06-08',
#   '2019-04-26': '2019-06-04',
#   '2019-04-21': '2019-06-18',
#   '2019-07-03': '2019-07-24',
#   '2023-03-21': '2023-04-06',
#   '2024-01-18': '2024-01-26',
#   nan: nan},
#  5: {'0': '5',
#   '2019-04-28': '2019-06-13',
#   '2019-04-26': '2019-06-07',
# ...

# %%
d=pd.read_csv('350.csv',header=None,index_col=0).to_dict()

# %%
d
# Out:
# {1: {'0': '1',
#   '2019-04-28': '2019-05-10',
#   '2019-04-26': '2019-05-04',
#   '2019-04-21': '2019-05-14',
#   '2019-07-03': '2019-07-03',
#   '2023-03-21': '2023-03-25',
#   '2024-01-18': '2024-01-20',
#   nan: nan},
#  2: {'0': '2',
#   '2019-04-28': '2019-06-06',
#   '2019-04-26': '2019-05-28',
#   '2019-04-21': '2019-06-09',
#   '2019-07-03': '2019-07-03',
#   '2023-03-21': '2023-03-27',
#   '2024-01-18': '2024-01-22',
#   nan: nan},
#  3: {'0': '3',
#   '2019-04-28': '2019-06-08',
#   '2019-04-26': '2019-06-03',
#   '2019-04-21': '2019-06-14',
#   '2019-07-03': '2019-07-14',
#   '2023-03-21': '2023-04-01',
#   '2024-01-18': '2024-01-22',
#   nan: nan},
#  4: {'0': '4',
#   '2019-04-28': '2019-06-08',
#   '2019-04-26': '2019-06-04',
#   '2019-04-21': '2019-06-18',
#   '2019-07-03': '2019-07-24',
#   '2023-03-21': '2023-04-06',
#   '2024-01-18': '2024-01-26',
#   nan: nan},
#  5: {'0': '5',
#   '2019-04-28': '2019-06-13',
#   '2019-04-26': '2019-06-07',
# ...

# %%
d=pd.read_csv('350.csv',header=None,index_col=0).to_dict()

# %%
d['B-304U']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 d['B-304U']
#
# KeyError: 'B-304U'

# %%
dd=pd.read_csv('350.csv',header=None,index_col=0).to_dict()

# %%
dd['B-304U']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 dd['B-304U']
#
# KeyError: 'B-304U'

# %%
d=pd.read_csv('350.csv',header=None,index_col=0).to_dict()

# %%
d
# Out:
# {1: {'0': '1',
#   '2019-04-28': '2019-05-10',
#   '2019-04-26': '2019-05-04',
#   '2019-04-21': '2019-05-14',
#   '2019-07-03': '2019-07-03',
#   '2023-03-21': '2023-03-25',
#   '2024-01-18': '2024-01-20',
#   nan: nan},
#  2: {'0': '2',
#   '2019-04-28': '2019-06-06',
#   '2019-04-26': '2019-05-28',
#   '2019-04-21': '2019-06-09',
#   '2019-07-03': '2019-07-03',
#   '2023-03-21': '2023-03-27',
#   '2024-01-18': '2024-01-22',
#   nan: nan},
#  3: {'0': '3',
#   '2019-04-28': '2019-06-08',
#   '2019-04-26': '2019-06-03',
#   '2019-04-21': '2019-06-14',
#   '2019-07-03': '2019-07-14',
#   '2023-03-21': '2023-04-01',
#   '2024-01-18': '2024-01-22',
#   nan: nan},
#  4: {'0': '4',
#   '2019-04-28': '2019-06-08',
#   '2019-04-26': '2019-06-04',
#   '2019-04-21': '2019-06-18',
#   '2019-07-03': '2019-07-24',
#   '2023-03-21': '2023-04-06',
#   '2024-01-18': '2024-01-26',
#   nan: nan},
#  5: {'0': '5',
#   '2019-04-28': '2019-06-13',
#   '2019-04-26': '2019-06-07',
# ...

# %%
print(d)
# Out:
# {1: {'0': '1', '2019-04-28': '2019-05-10', '2019-04-26': '2019-05-04', '2019-04-21': '2019-05-14', '2019-07-03': '2019-07-03', '2023-03-21': '2023-03-25', '2024-01-18': '2024-01-20', nan: nan}, 2: {'0': '2', '2019-04-28': '2019-06-06', '2019-04-26': '2019-05-28', '2019-04-21': '2019-06-09', '2019-07-03': '2019-07-03', '2023-03-21': '2023-03-27', '2024-01-18': '2024-01-22', nan: nan}, 3: {'0': '3', '2019-04-28': '2019-06-08', '2019-04-26': '2019-06-03', '2019-04-21': '2019-06-14', '2019-07-03': '2019-07-14', '2023-03-21': '2023-04-01', '2024-01-18': '2024-01-22', nan: nan}, 4: {'0': '4', '2019-04-28': '2019-06-08', '2019-04-26': '2019-06-04', '2019-04-21': '2019-06-18', '2019-07-03': '2019-07-24', '2023-03-21': '2023-04-06', '2024-01-18': '2024-01-26', nan: nan}, 5: {'0': '5', '2019-04-28': '2019-06-13', '2019-04-26': '2019-06-07', '2019-04-21': '2019-07-13', '2019-07-03': '2019-08-15', '2023-03-21': '2023-04-12', '2024-01-18': '2024-02-02', nan: nan}, 6: {'0': '6', '2019-04-28': '201
# ...

# %%
dict_from_csv=pd.read_csv('350.csv',header=None,index_col=0).to_dict()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 dict_from_csv=pd.read_csv('350.csv',header=None,index_col=0).to_dict()
#
# File D:\Program Files\anaconda\envs\airnav\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
dict_from_csv=pd.read_csv('350.csv',header=None,index_col=0).to_dict()

# %%
dict_from_csv
# Out:
# {1: {'0': '1',
#   '2019-04-28': '2019-05-10',
#   '2019-04-26': '2019-05-04',
#   '2019-04-21': '2019-05-14',
#   '2019-07-03': '2019-07-03',
#   '2023-03-21': '2023-03-25',
#   '2024-01-18': '2024-01-20',
#   nan: nan},
#  2: {'0': '2',
#   '2019-04-28': '2019-06-06',
#   '2019-04-26': '2019-05-28',
#   '2019-04-21': '2019-06-09',
#   '2019-07-03': '2019-07-03',
#   '2023-03-21': '2023-03-27',
#   '2024-01-18': '2024-01-22',
#   nan: nan},
#  3: {'0': '3',
#   '2019-04-28': '2019-06-08',
#   '2019-04-26': '2019-06-03',
#   '2019-04-21': '2019-06-14',
#   '2019-07-03': '2019-07-14',
#   '2023-03-21': '2023-04-01',
#   '2024-01-18': '2024-01-22',
#   nan: nan},
#  4: {'0': '4',
#   '2019-04-28': '2019-06-08',
#   '2019-04-26': '2019-06-04',
#   '2019-04-21': '2019-06-18',
#   '2019-07-03': '2019-07-24',
#   '2023-03-21': '2023-04-06',
#   '2024-01-18': '2024-01-26',
#   nan: nan},
#  5: {'0': '5',
#   '2019-04-28': '2019-06-13',
#   '2019-04-26': '2019-06-07',
# ...

# %%
d=pd.read_csv('350.csv',header=None,index_col=0).to_dict()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12568\3806016250.py in <module>
# ----> 1 d=pd.read_csv('350.csv',header=None,index_col=0).to_dict()
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
d=pd.read_csv('350.csv',header=None,index_col=0).to_dict()

# %%
d
# Out:
# {1: {'0': '1',
#   '2019-04-28': '2019-05-10',
#   '2019-04-26': '2019-05-04',
#   '2019-04-21': '2019-05-14',
#   '2019-07-03': '2019-07-03',
#   '2023-03-21': '2023-03-25',
#   '2024-01-18': '2024-01-20',
#   nan: nan},
#  2: {'0': '2',
#   '2019-04-28': '2019-06-06',
#   '2019-04-26': '2019-05-28',
#   '2019-04-21': '2019-06-09',
#   '2019-07-03': '2019-07-03',
#   '2023-03-21': '2023-03-27',
#   '2024-01-18': '2024-01-22',
#   nan: nan},
#  3: {'0': '3',
#   '2019-04-28': '2019-06-08',
#   '2019-04-26': '2019-06-03',
#   '2019-04-21': '2019-06-14',
#   '2019-07-03': '2019-07-14',
#   '2023-03-21': '2023-04-01',
#   '2024-01-18': '2024-01-22',
#   nan: nan},
#  4: {'0': '4',
#   '2019-04-28': '2019-06-08',
#   '2019-04-26': '2019-06-04',
#   '2019-04-21': '2019-06-18',
#   '2019-07-03': '2019-07-24',
#   '2023-03-21': '2023-04-06',
#   '2024-01-18': '2024-01-26',
#   nan: nan},
#  5: {'0': '5',
#   '2019-04-28': '2019-06-13',
#   '2019-04-26': '2019-06-07',
# ...

# %%
d[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12568\1089268471.py in <module>
# ----> 1 d[0]
#
# KeyError: 0

# %%
d[1]
# Out:
# {'0': '1',
#  '2019-04-28': '2019-05-10',
#  '2019-04-26': '2019-05-04',
#  '2019-04-21': '2019-05-14',
#  '2019-07-03': '2019-07-03',
#  '2023-03-21': '2023-03-25',
#  '2024-01-18': '2024-01-20',
#  nan: nan}

# %%
cd amro
# Out:
# D:\learing\airnavX\amro

# %%
cd amro/
# Out:
# D:\learing\airnavX\amro

# %%
run wheels_time.py
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i

# %%
run amro_fl.py
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i
# B-32D2主轮更换频率
# 1号轮
# 168
# 201
# 2号轮
# 223
# 257
# 3号轮
# 184
# 252
# 4号轮
# 434 2023-07-24 2024-03-08
# 5号轮
# 208
# 170
# 6号轮
# 187
# 105 2023-10-11 2023-11-26
# 180
# 7号轮
# 266
# 181
# 8号轮
# 476 2023-07-16 2024-03-20
# B-6535主轮更换频率
# 1号轮
# 60 2019-06-15 2019-07-06
# 10 2019-07-06 2019-07-08
# 172
# 237
# 213
# 238
# 232
# 218
# 218
# 239
# 196
# 254
# 230
# 174
# 198
# 2号轮
# 54 2019-06-19 2019-07-08
# 270
# 303 2019-11-01 2020-07-27
# 204
# 618 2020-10-04 2021-08-01
# 256
# 527 2022-03-23 2023-04-22
# 503 2023-04-22 2023-11-30
# 216
# 3号轮
# 4 2019-06-15 2019-06-15
# 278
# 336 2019-10-07 2020-07-18
# 235
# 324 2020-10-07 2021-04-08
# 263
# 178
# 276
# 203
# 298
# 348 2023-07-12 2023-11-24
# 212
# 4号轮
# 248
# 146 2019-08-07 2019-10-10
# 249
# ...

# %%
import selenium

# %%
import json

# %%
with open('wheels_fl.json','r',encoding='utf-8') as f:
    d=json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 with open('wheels_fl.json','r',encoding='utf-8') as f:
#       2     d=json.load(f)
#
# File D:\programing\anaconda\envs\airnav\lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'wheels_fl.json'
