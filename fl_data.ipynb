# %% [markdown]
# #

# %%
run amro_fl.py
# Out:
# The geckodriver version (0.34.0) detected in PATH at /usr/local/bin/geckodriver might not be compatible with the detected firefox version (88.0); currently, geckodriver 0.30.0 is recommended for firefox 88.*, so it is advised to delete the driver in PATH and retry
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i

# %%
run amro_fl.py
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/home/lee/miniconda3/envs/airnav/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/lee/miniconda3/envs/airnav/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/lee/miniconda3/envs/airnav/lib/python3.9/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
# ...

# %%
run amro_fl.py
# Out:
# The geckodriver version (0.34.0) detected in PATH at /usr/local/bin/geckodriver might not be compatible with the detected firefox version (88.0); currently, geckodriver 0.30.0 is recommended for firefox 88.*, so it is advised to delete the driver in PATH and retry
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i
# B-32D2主轮更换频率
# 1号轮
# 168
# 201
# 2号轮
# 223
# 257 2023-10-31 2024-04-02
# 3号轮
# 184
# 252 2023-10-08 2024-03-08
# 4号轮
# 434 2023-07-24 2024-03-08
# 5号轮
# 208
# 170
# 6号轮
# 187
# 105 2023-10-11 2023-11-26
# 180
# 7号轮
# 266 2023-07-18 2023-11-08
# 181
# 8号轮
# 476 2023-07-16 2024-03-20
# B-6535主轮更换频率
# 1号轮
# 60 2019-06-15 2019-07-06
# 10 2019-07-06 2019-07-08
# 172
# 237
# 213
# 238
# 232
# 218
# 218
# 239
# 196
# 254 2023-01-29 2023-05-01
# 230
# 174
# 198
# 2号轮
# ...

# %%
run amro_fl.py
# Out:
# Problem reading geckodriver versions: error sending request for url (https://raw.githubusercontent.com/SeleniumHQ/selenium/trunk/common/geckodriver/geckodriver-support.json): error trying to connect: dns error: 请求的名称有效，但是找不到请求的类型的数据。 (os error 11004). Using latest geckodriver version
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i
# B-32D2主轮更换频率
# 1号轮
# 168
# 201
# 2号轮
# 223
# 257
# 3号轮
# 184
# 252
# 4号轮
# 434 2023-07-24更换3#、4#主轮，检查测试正常。 2024-03-08依据AMM32-41-11更换4号主轮，检测正常
# 5号轮
# 208
# 170
# 6号轮
# 187
# 105 2023-10-11依据手册，更换5号，6号主轮，检查测试正常 2023-11-26更换6号主轮，检查测试正常。
# 180
# 7号轮
# 266
# 181
# 8号轮
# 476 2023-07-16更换8号主轮，检查测试正常。 2024-03-20依据手册，更换八号主轮，检查测试正常。
# B-6535主轮更换频率
# 1号轮
# 60 2019-06-15短停依据AMM32-41-11,更换3号主轮，检查正常。拆装记录详见另外一条记录。 2019-07-06短停更换1#主轮，测试正常。
# ...

# %%
run amro_fl.py
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i
# B-32D2主轮更换频率
# 1号轮
# 168
# 201
# 2号轮
# 223
# 257
# 3号轮
# 184
# 252
# 4号轮
# 54 2023-07-24更换3#、4#主轮，检查测试正常。 2023-08-16专项工作：更换受影响的机轮
# 380 2023-08-16专项工作：更换受影响的机轮 2024-03-08依据AMM32-41-11更换4号主轮，检测正常
# 5号轮
# 72 2023-07-16更换5号主轮，检查测试正常。 2023-08-16专项工作：更换受影响的机轮
# 136 2023-08-16专项工作：更换受影响的机轮 2023-10-11依据手册，更换5号，6号主轮，检查测试正常
# 170
# 6号轮
# 51 2023-07-25更换6#主轮，检测正常。 2023-08-16专项工作：更换受影响的机轮
# 136 2023-08-16专项工作：更换受影响的机轮 2023-10-11依据手册，更换5号，6号主轮，检查测试正常
# 105 2023-10-11依据手册，更换5号，6号主轮，检查测试正常 2023-11-26更换6号主轮，检查测试正常。
# 180
# 7号轮
# 266
# 181
# 8号轮
# 78 2023-07-16更换8号主轮，检查测试正常。 2023-08-18专项工作：更换受影响的机轮
# 190
# 213
# 199
# B-6535主轮更换频率
# 1号轮
# 178
# 237
# 213
# 238
# 232
# 218
# 218
# 239
# 196
# 254
# 230
# 174
# 198
# 2号轮
# ...

# %%
def save_dict(dictionary, file_path):
    with open(file_path, 'w') as file:
        json.dump(dictionary, file)

# %%
save_dict(times,'wheels_fl.json')

# %%
times
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 times
#
# NameError: name 'times' is not defined

# %%
import json

# %%
with open('wheels_fl.json','r',encoding='utf-8') as f:
    d=json.loads(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 with open('wheels_fl.json','r',encoding='utf-8') as f:
# ----> 2     d=json.loads(f)
#
# File D:\Program Files\anaconda\envs\airnav\lib\json\__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
# --> 339         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                         f'not {s.__class__.__name__}')
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
#
# ...

# %%
with open ('wheels_fl.json','r') as f:
    d=json.load(f)

# %%
with open('wheels_fl.json','w',encoding='utf-8') as f:
    json.dump(d,f,ensure_ascii=False)

# %%
with open ('wheels_fl.json','r') as f:
    d=json.load(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 with open ('wheels_fl.json','r') as f:
# ----> 2     d=json.load(f)
#
# NameError: name 'json' is not defined

# %%
import json

# %%
import scipy

# %%
with open ('wheels_fl.json','r') as f:
    d=json.load(f)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[4], line 2
#       1 with open ('wheels_fl.json','r') as f:
# ----> 2     d=json.load(f)
#
# File D:\Program Files\anaconda\envs\airnav\lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
# ...

# %%
with open('wheels_fl.json','r',encoding='utf-8') as f:
    json.dump(d,f,ensure_ascii=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 with open('wheels_fl.json','r',encoding='utf-8') as f:
# ----> 2     json.dump(d,f,ensure_ascii=False)
#
# NameError: name 'd' is not defined

# %%
with open('wheels_fl.json','w',encoding='utf-8') as f:
    json.dump(f,ensure_ascii=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 with open('wheels_fl.json','w',encoding='utf-8') as f:
# ----> 2     json.dump(f,ensure_ascii=False)
#
# TypeError: dump() missing 1 required positional argument: 'fp'

# %%
with open('wheels_fl.json','r',encoding='utf-8') as f:
    json.dump(f,ensure_ascii=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 with open('wheels_fl.json','r',encoding='utf-8') as f:
# ----> 2     json.dump(f,ensure_ascii=False)
#
# TypeError: dump() missing 1 required positional argument: 'fp'

# %%
with open('wheels_fl.json','r',encoding='utf-8') as f:
    json.dump(f,ensure_ascii=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 with open('wheels_fl.json','r',encoding='utf-8') as f:
# ----> 2     json.dump(f,ensure_ascii=False)
#
# TypeError: dump() missing 1 required positional argument: 'fp'

# %%
with open('wheels_fl.json','r',encoding='utf-8') as f:
    json.load(f,ensure_ascii=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 with open('wheels_fl.json','r',encoding='utf-8') as f:
# ----> 2     json.load(f,ensure_ascii=False)
#
# File D:\Program Files\anaconda\envs\airnav\lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
# ...

# %%
with open('wheels_fl.json','r',encoding='utf-8') as f:
    json.dump(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 with open('wheels_fl.json','r',encoding='utf-8') as f:
# ----> 2     json.dump(f)
#
# TypeError: dump() missing 1 required positional argument: 'fp'

# %%
with open('wheels_fl.json','r',encoding='utf-8') as f:
    json.load(f)

# %%
with open('wheels_fl.json','r',encoding='utf-8') as f:
    d=json.load(f)

# %%
for i in d:
    for j in d[i]:
        for k in d[i][j]:
            print(k[0])
# Out:
# [168, '2023-07-26依据手册，更换1号主轮，检查测试正常。', '2023-10-03更换1号主轮，检查测试正常。']
# [223, '2023-07-31更换2号主轮，检查测试正常。', '2023-10-31更换2号主轮，检查测试正常。']
# [184, '2023-07-24更换3#、4#主轮，检查测试正常。', '2023-10-08更换3号主轮，检查正常。']
# [54, '2023-07-24更换3#、4#主轮，检查测试正常。', '2023-08-16专项工作：更换受影响的机轮']
# [72, '2023-07-16更换5号主轮，检查测试正常。', '2023-08-16专项工作：更换受影响的机轮']
# [51, '2023-07-25更换6#主轮，检测正常。', '2023-08-16专项工作：更换受影响的机轮']
# [266, '2023-07-18更换7号主轮，检查测试正常。', '2023-11-08更换7号主轮，检查正常。']
# [78, '2023-07-16更换8号主轮，检查测试正常。', '2023-08-18专项工作：更换受影响的机轮']
# [178, '2019-07-06短停更换1#主轮，测试正常。', '2019-09-17依据AMM32-41-11，更换1#主轮，检查测试正常。']
# [320, '2019-06-19依据AMM32-41-11更换2#主轮，检查正常。', '2019-11-01航后更换2号主轮，检查测试正常。']
# [4, '2019-06-15短停依据AMM32-41-11,更换3号主轮，检查正常。拆装记录详见另外一条记录。', '2019-06-15根据AMM32-41-11,更换3#主轮，测试正常。']
# [248, '2019-04-19航后根据AMM32-41-11更换4号主轮，测试检查正常。', '2019-08-07航后更换4号主轮，检查测试正常。']
# [182, '2019-04-15依据AMM32-41-11,更换5号主轮，检查正常。', '2019-07-08航后更换5号主轮，检查测试正常，胎压215PSI。']
# [188, '2019-08-05航后更换6号主轮，检查测试正常', '2019-10-27航后更换6#主轮，检查正常。']
# ...

# %%
dd=[]
for i in d:
    print(i)
# Out:
# 330
# 350

# %%
for i in d:
    for j in d[i]:
        print(j)
# Out:
# B-32D2
# B-6535
# B-308L
# B-308P
# B-5923
# B-308Q
# B-5929
# B-5945
# B-5960
# B-8332
# B-8468
# B-8962
# B-8690
# B-8589
# B-308F
# B-304U
# B-304V
# B-301D
# B-306N
# B-325J
# B-32AG

# %%
for i in d:
    for j in d[i]:
        for k in d[i][j]:
            print(k)
# Out:
# [[168, '2023-07-26依据手册，更换1号主轮，检查测试正常。', '2023-10-03更换1号主轮，检查测试正常。'], [201, '2023-10-03更换1号主轮，检查测试正常。', '2023-12-26更换1#主轮。检查测试正常。']]
# [[223, '2023-07-31更换2号主轮，检查测试正常。', '2023-10-31更换2号主轮，检查测试正常。'], [257, '2023-10-31更换2号主轮，检查测试正常。', '2024-04-02更换2号主轮，检查测试正常。']]
# [[184, '2023-07-24更换3#、4#主轮，检查测试正常。', '2023-10-08更换3号主轮，检查正常。'], [252, '2023-10-08更换3号主轮，检查正常。', '2024-03-08依据AMM32-41-11更换3号主轮，检测正常']]
# [[54, '2023-07-24更换3#、4#主轮，检查测试正常。', '2023-08-16专项工作：更换受影响的机轮'], [380, '2023-08-16专项工作：更换受影响的机轮', '2024-03-08依据AMM32-41-11更换4号主轮，检测正常']]
# [[72, '2023-07-16更换5号主轮，检查测试正常。', '2023-08-16专项工作：更换受影响的机轮'], [136, '2023-08-16专项工作：更换受影响的机轮', '2023-10-11依据手册，更换5号，6号主轮，检查测试正常'], [170, '2023-10-11依据手册，更换5号，6号主轮，检查测试正常', '2023-12-21依据手册AMM 32-41-11,更换5号主轮，检测正常。']]
# ...

# %%
for i in d:
    for j in d[i]:
        for k in d[i][j]:
            for l in d[i][j][k]:
                print(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       2 for j in d[i]:
#       3     for k in d[i][j]:
# ----> 4         for l in d[i][j][k]:
#       5             print(l)
#
# TypeError: list indices must be integers or slices, not list

# %%
d[0][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 d[0][0]
#
# KeyError: 0

# %%
d['330']['B-32d2']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 d['330']['B-32d2']
#
# KeyError: 'B-32d2'

# %%
d['330']['B-32D2']
# Out:
# [[[168, '2023-07-26依据手册，更换1号主轮，检查测试正常。', '2023-10-03更换1号主轮，检查测试正常。'],
#   [201, '2023-10-03更换1号主轮，检查测试正常。', '2023-12-26更换1#主轮。检查测试正常。']],
#  [[223, '2023-07-31更换2号主轮，检查测试正常。', '2023-10-31更换2号主轮，检查测试正常。'],
#   [257, '2023-10-31更换2号主轮，检查测试正常。', '2024-04-02更换2号主轮，检查测试正常。']],
#  [[184, '2023-07-24更换3#、4#主轮，检查测试正常。', '2023-10-08更换3号主轮，检查正常。'],
#   [252, '2023-10-08更换3号主轮，检查正常。', '2024-03-08依据AMM32-41-11更换3号主轮，检测正常']],
#  [[54, '2023-07-24更换3#、4#主轮，检查测试正常。', '2023-08-16专项工作：更换受影响的机轮'],
#   [380, '2023-08-16专项工作：更换受影响的机轮', '2024-03-08依据AMM32-41-11更换4号主轮，检测正常']],
#  [[72, '2023-07-16更换5号主轮，检查测试正常。', '2023-08-16专项工作：更换受影响的机轮'],
#   [136, '2023-08-16专项工作：更换受影响的机轮', '2023-10-11依据手册，更换5号，6号主轮，检查测试正常'],
#   [170,
#    '2023-10-11依据手册，更换5号，6号主轮，检查测试正常',
#    '2023-12-21依据手册AMM 32-41-11,更换5号主轮，检测正常。']],
#  [[51, '2023-07-25更换6#主轮，检测正常。', '2023-08-16专项工作：更换受影响的机轮'],
#   [136, '2023-08-16专项工作：更换受影响的机轮', '2023-10-11依据手册，更换5号，6号主轮，检查测试正常'],
# ...

# %%
d['330']['B-32D2'][0]
# Out:
# [[168, '2023-07-26依据手册，更换1号主轮，检查测试正常。', '2023-10-03更换1号主轮，检查测试正常。'],
#  [201, '2023-10-03更换1号主轮，检查测试正常。', '2023-12-26更换1#主轮。检查测试正常。']]

# %%
len(d['330']['B-32D2'])
# Out:
# 8

# %%
for i in d:
    for j in d[i]:
        for k in d[i][j]:
            for l in d[i][j][k]:
                print(l[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       2 for j in d[i]:
#       3     for k in d[i][j]:
# ----> 4         for l in d[i][j][k]:
#       5             print(l[0])
#
# TypeError: list indices must be integers or slices, not list

# %%
i,j,k
# Out:
# ('330',
#  'B-32D2',
#  [[168, '2023-07-26依据手册，更换1号主轮，检查测试正常。', '2023-10-03更换1号主轮，检查测试正常。'],
#   [201, '2023-10-03更换1号主轮，检查测试正常。', '2023-12-26更换1#主轮。检查测试正常。']])

# %%
k
# Out:
# [[168, '2023-07-26依据手册，更换1号主轮，检查测试正常。', '2023-10-03更换1号主轮，检查测试正常。'],
#  [201, '2023-10-03更换1号主轮，检查测试正常。', '2023-12-26更换1#主轮。检查测试正常。']]

# %%
for i in d:
    for j in d[i]:
        for k in d[i][j]:
            for l in k:
                print(l[0])
# Out:
# 168
# 201
# 223
# 257
# 184
# 252
# 54
# 380
# 72
# 136
# 170
# 51
# 136
# 105
# 180
# 266
# 181
# 78
# 190
# 213
# 199
# 178
# 237
# 213
# 238
# 232
# 218
# 218
# 239
# 196
# 254
# 230
# 174
# 198
# 320
# 303
# 204
# 618
# 256
# 527
# 503
# 216
# 4
# 278
# 336
# 235
# 324
# 263
# 178
# 276
# 203
# 298
# 348
# 212
# 248
# 146
# 249
# 198
# 241
# 235
# 192
# 444
# 233
# 218
# 239
# 196
# 175
# 182
# 202
# 424
# 232
# 232
# 202
# 685
# 245
# 344
# 158
# 188
# 294
# 173
# 250
# 256
# 54
# 177
# 210
# 20
# 192
# 293
# 250
# 179
# 184
# 224
# 282
# 178
# 217
# 232
# 185
# 189
# 242
# 189
# 244
# 234
# 224
# 247
# 198
# 239
# 170
# 202
# 224
# 182
# 172
# 182
# 205
# 139
# 187
# 253
# 324
# 155
# 489
# 188
# 420
# 676
# 270
# 170
# 481
# 225
# 164
# 150
# 173
# 177
# 252
# 182
# 253
# 310
# 212
# 333
# 239
# 255
# 307
# 267
# 251
# 371
# 267
# 515
# 253
# 241
# 211
# 533
# 288
# 297
# 257
# 290
# 362
# 218
# 430
# 226
# 214
# 251
# 212
# 292
# 223
# 251
# 211
# 308
# 240
# 504
# 223
# 214
# ...

# %%
cycle=[]
for i in d:
    for j in d[i]:
        for k in d[i][j]:
            for l in k:
                cycle.append(l[0])

# %%
import matplotlib.pyplot as plt

# %%
len(cycle)
# Out:
# 2035

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.arry(len(cycle))
y=np.arry(cycle)

plt.plot(x, y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 4
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 4 x=np.arry(len(cycle))
#       5 y=np.arry(cycle)
#       7 plt.plot(x, y)
#
# File D:\Program Files\anaconda\envs\airnav\lib\site-packages\numpy\__init__.py:333, in __getattr__(attr)
#     330     "Removed in NumPy 1.25.0"
#     331     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 333 raise AttributeError("module {!r} has no attribute "
#     334                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'arry'

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(len(cycle))
y=np.array(cycle)

plt.plot(x, y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 7
#       4 x=np.array(len(cycle))
#       5 y=np.array(cycle)
# ----> 7 plt.plot(x, y)
#       8 plt.show()
#
# File D:\Program Files\anaconda\envs\airnav\lib\site-packages\matplotlib\pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# File D:\Program Files\anaconda\envs\airnav\lib\site-packages\matplotlib\axes\_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
# ...

# %%
cycle
# Out:
# [168,
#  201,
#  223,
#  257,
#  184,
#  252,
#  54,
#  380,
#  72,
#  136,
#  170,
#  51,
#  136,
#  105,
#  180,
#  266,
#  181,
#  78,
#  190,
#  213,
#  199,
#  178,
#  237,
#  213,
#  238,
#  232,
#  218,
#  218,
#  239,
#  196,
#  254,
#  230,
#  174,
#  198,
#  320,
#  303,
#  204,
#  618,
#  256,
#  527,
#  503,
#  216,
#  4,
#  278,
#  336,
#  235,
#  324,
#  263,
#  178,
#  276,
#  203,
#  298,
#  348,
#  212,
#  248,
#  146,
#  249,
#  198,
#  241,
#  235,
#  192,
#  444,
#  233,
#  218,
#  239,
#  196,
#  175,
#  182,
#  202,
#  424,
#  232,
#  232,
#  202,
#  685,
#  245,
#  344,
#  158,
#  188,
#  294,
#  173,
#  250,
#  256,
#  54,
#  177,
#  210,
#  20,
#  192,
#  293,
#  250,
#  179,
#  184,
#  224,
#  282,
#  178,
#  217,
#  232,
#  185,
#  189,
#  242,
#  189,
#  244,
#  234,
#  224,
#  247,
#  198,
#  239,
#  170,
#  202,
#  224,
#  182,
#  172,
#  182,
#  205,
#  139,
#  187,
#  253,
#  324,
#  155,
#  489,
#  188,
#  420,
#  676,
#  270,
#  170,
#  481,
#  225,
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(range(len(cycle)))
y=np.array(cycle)

plt.plot(x, y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 4
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 4 x=np.arry(range(len(cycle)))
#       5 y=np.arry(cycle)
#       7 plt.plot(x, y)
#
# File D:\Program Files\anaconda\envs\airnav\lib\site-packages\numpy\__init__.py:333, in __getattr__(attr)
#     330     "Removed in NumPy 1.25.0"
#     331     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 333 raise AttributeError("module {!r} has no attribute "
#     334                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'arry'

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(range(len(cycle)))
y=np.array(cycle)

plt.plot(x, y)
plt.show()

# %%
import numpy as np
import scipy.stats as st
  

  
# create 90% confidence interval
st.t.interval(0.90, df=len(cycle)-1,
              loc=np.mean(cycle),
              scale=st.sem(cycle))
# Out:
# (232.5915402341466, 239.5381894955831)

# %%
import numpy as np
import scipy.stats as st
  

  
# create 90% confidence interval
st.t.interval(0.95, df=len(cycle)-1,
              loc=np.mean(cycle),
              scale=st.sem(cycle))
# Out:
# (231.92556515107935, 240.20416457865036)

# %%
with open('wheels_fl.json','r',encoding='utf-8') as f:
    d=json.load(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 with open('wheels_fl.json','r',encoding='utf-8') as f:
# ----> 2     d=json.load(f)
#
# NameError: name 'json' is not defined

# %%
import json
with open('wheels_fl.json','r',encoding='utf-8') as f:
    d=json.load(f)
cycle=[]
for i in d:
    for j in d[i]:
        for k in d[i][j]:
            for l in k:
                cycle.append(l[0])
import matplotlib.pyplot as plt
import numpy as np
data=np.array(cycle)
plt.hist(data, bins=25, density=True, alpha=0.6, color='b')
plt.show()

# %%
run brake_times.py
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i
# username: 018608
# password: 7400233@scal
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File D:\learing\airnavX\amro\brake_times.py:94
#      92             if re.search('3-1546-53', chtl_list['VPN']):
#      93                 return i
# ---> 94 whrp=list(filter(whrp1,whrp_data))#筛选更换工作包
#      97 "飞机号导入"
#      98 with open('fl.json','r') as f:
#
# File D:\learing\airnavX\amro\brake_times.py:90, in whrp1(i)
#      88 chtl_data=chtl.content.decode('utf-8')
#      89 chtl_str=json.loads(chtl_data)
# ---> 90 chtl_list=chtl_str['data'][0]
#      91 if 'VPN' in chtl_list:
#      92     if re.search('3-1546-53', chtl_list['VPN']):
#
# ...

# %%
run brakes_fl.py
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i
# username: 018608
# password: 7400233@scal
# B-32D2刹车更换频率
# 1号刹车
# 2号刹车
# 3号刹车
# 4号刹车
# 5号刹车
# 6号刹车
# 7号刹车
# 8号刹车
# B-6535刹车更换频率
# 1号刹车
# 999 2019-11-01航后更换一号刹车，由于刹车轴套与刹车咬死，无法单独取下刹车，与刹车一起取下更换新轴套和新刹车，检查测试正常。 2023-07-02依据手册更换1号刹车，检查测试正常
# 2号刹车
# 533 2019-08-05航后更换2号刹车，检查测试正常 2020-08-09航后依据手册，更换七号刹车，检查测试正常，因飞机停放229机位无法连接电源，没有进行温度传感器插头处热缩，已用电工胶带临时处理，并于交班表上做记录，飞机换机位后再做热缩工作。
# 502 2020-08-09航后依据手册，更换七号刹车，检查测试正常，因飞机停放229机位无法连接电源，没有进行温度传感器插头处热缩，已用电工胶带临时处理，并于交班表上做记录，飞机换机位后再做热缩工作。 2021-04-08航后更换2#刹车，检查测试正常。
# 999 2021-04-08航后更换2#刹车，检查测试正常。 2023-09-16依据手册AMM更换2#刹车组件，检查测试正常。
# 3号刹车
# 999 2020-08-25航后更换3号刹车，检查测试正常。 2022-07-30依据手册更换3号刹车，检查测试正常。
# 4号刹车
# 523 2021-10-29航后更换4号刹车，检查测试正常 2023-03-04航后依据AMM手册，更换4号刹车，检查测试正常。
# 5号刹车
# ...

# %%
run brakes_fl.py
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 谷歌reCaptcha验证码 / hCaptcha验证码 / funCaptcha验证码商业级识别接口：https://yescaptcha.com/i/NSwk7i
# username: 018608
# password: 7400233@scal
# B-32D2刹车更换频率
# 1号刹车
# 2号刹车
# 3号刹车
# 4号刹车
# 5号刹车
# 6号刹车
# 7号刹车
# 8号刹车
# B-6535刹车更换频率
# 1号刹车
# 1997 2019-11-01航后更换一号刹车，由于刹车轴套与刹车咬死，无法单独取下刹车，与刹车一起取下更换新轴套和新刹车，检查测试正常。 2023-07-02依据手册更换1号刹车，检查测试正常
# 2号刹车
# 533 2019-08-05航后更换2号刹车，检查测试正常 2020-08-09航后依据手册，更换七号刹车，检查测试正常，因飞机停放229机位无法连接电源，没有进行温度传感器插头处热缩，已用电工胶带临时处理，并于交班表上做记录，飞机换机位后再做热缩工作。
# 502 2020-08-09航后依据手册，更换七号刹车，检查测试正常，因飞机停放229机位无法连接电源，没有进行温度传感器插头处热缩，已用电工胶带临时处理，并于交班表上做记录，飞机换机位后再做热缩工作。 2021-04-08航后更换2#刹车，检查测试正常。
# 1420 2021-04-08航后更换2#刹车，检查测试正常。 2023-09-16依据手册AMM更换2#刹车组件，检查测试正常。
# 3号刹车
# 1168 2020-08-25航后更换3号刹车，检查测试正常。 2022-07-30依据手册更换3号刹车，检查测试正常。
# 4号刹车
# 523 2021-10-29航后更换4号刹车，检查测试正常 2023-03-04航后依据AMM手册，更换4号刹车，检查测试正常。
# 5号刹车
# ...

# %%
run plot.py
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File D:\learing\airnavX\amro\plot.py:13
#       9 import numpy as np
#      12 with open('wheels_fl.json','r') as f:
# ---> 13     d=json.load(f)
#      15 cycle=[]
#      16 for i in d:
#
# File D:\Program Files\anaconda\envs\airnav\lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
# ...

# %%
run plot.py

# %%
run plot.py

# %%
run plot.py
# Out:
# 置信区间为：0.9(232.5915402341466, 239.5381894955831)，0.95：(231.92556515107935, 240.20416457865036)

# %%
CI_90
# Out:
# (232.5915402341466, 239.5381894955831)

# %%
type(CI_90)
# Out:
# tuple

# %%
CI_90[0]
# Out:
# 232.5915402341466

# %%
run plot.py
# Out:
# 置信区间为：0.9:(232.5915402341466, 239.5381894955831)，0.95：(231.92556515107935, 240.20416457865036)

# %%
CI_95,CI_90
# Out:
# ((231.92556515107935, 240.20416457865036),
#  (232.5915402341466, 239.5381894955831))

# %%
plt.plot([0,CI_95[0]],[len(cycle),CI_95[1]])

# %%
y=np.array(CI_90)

# %%
x=np.array(range(len(cycle)))

# %%
plt.plot(x, y, lw=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 plt.plot(x, y, lw=1)
#
# File D:\Program Files\anaconda\envs\airnav\lib\site-packages\matplotlib\pyplot.py:3590, in plot(scalex, scaley, data, *args, **kwargs)
#    3582 @_copy_docstring_and_deprecators(Axes.plot)
#    3583 def plot(
#    3584     *args: float | ArrayLike | str,
#    (...)
#    3588     **kwargs,
#    3589 ) -> list[Line2D]:
# -> 3590     return gca().plot(
#    3591         *args,
#    3592         scalex=scalex,
#    3593         scaley=scaley,
#    3594         **({"data": data} if data is not None else {}),
#    3595         **kwargs,
#    3596     )
#
# File D:\Program Files\anaconda\envs\airnav\lib\site-packages\matplotlib\axes\_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
# ...

# %%
plt.plot([0,CI_90[0]],[len(cycle),CI_90[0]],color='red',lw=1)
plt.plot([0,CI_90[1]],[len(cycle),CI_90[1]],color='red',lw=1)

# %%
CI_90
# Out:
# (232.5915402341466, 239.5381894955831)

# %%
plt.plot([0,CI_90[0]],[len(cycle),CI_90[0]],color='red',lw=2)

# %%
int(CI_90[0])
# Out:
# 232

# %%
plt.plot([0,int(CI_90[0]]),[len(cycle),int(CI_90[0])],color='red',lw=2)
# Out:
#   Cell In[22], line 1
#     plt.plot([0,int(CI_90[0]]),[len(cycle),int(CI_90[0])],color='red',lw=2)
#                             ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %%
plt.plot([0,int(CI_90[0])]),[len(cycle),int(CI_90[0])],color='red',lw=2)
# Out:
#   Cell In[23], line 1
#     plt.plot([0,int(CI_90[0])]),[len(cycle),int(CI_90[0])],color='red',lw=2)
#     ^
# SyntaxError: cannot assign to function call

# %%
int(CI_90)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 int(CI_90)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'tuple'

# %%
plt.plot([0,int(CI_90[0])],[len(cycle),int(CI_90[0])],color='red',lw=2)

# %%
plt.plot([0,len(cycle)],[int(CI_90[0]),int(CI_90[0])],color='red',lw=2)

# %%
plt.plot([0,len(cycle)],[int(CI_90[0]),int(CI_90[0])],color='red',lw=2)
plt.plot([0,len(cycle)],[int(CI_90[1]),int(CI_90[1])],color='red',lw=2)

# %%
run plot.py
# Out:
# 置信区间为：0.9:(232.5915402341466, 239.5381894955831)，0.95：(231.92556515107935, 240.20416457865036)

# %%
run plot.py
# Out:
# 置信区间为：0.9:(232.5915402341466, 239.5381894955831)，0.95：(231.92556515107935, 240.20416457865036)

# %%
run plot.py
# Out:
# 置信区间为：0.9:(232.5915402341466, 239.5381894955831)，0.95：(231.92556515107935, 240.20416457865036)

# %%
run plot.py
# Out:
# 置信区间为：0.9:(232.5915402341466, 239.5381894955831)，0.95：(231.92556515107935, 240.20416457865036)

# %%
run plot.py
# Out:
# 置信区间为：0.9:(1203.5440094677717, 1280.967618439205)，0.95：(1196.0766640406143, 1288.4349638663623)

# %%
run plot.py
# Out:
# 置信区间为：0.9:(1203.5440094677717, 1280.967618439205)，0.95：(1196.0766640406143, 1288.4349638663623)
